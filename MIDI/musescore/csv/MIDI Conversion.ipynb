# %% [markdown]
# # Implementation

# %%
import mido
import csv
import audiolazy

# %%
def get_active_notes(mid):
    active_notes = {}
    tracks = mid.tracks
    num_tracks = len(tracks)
    all_notes = num_tracks * [None]
    for i in range(0, num_tracks):
        track = tracks[i]
        time = 0
        all_notes[i] = []
        for msg in track:
            msg_dict = msg.dict()
            time += msg_dict['time']
            if msg.type == 'note_on':
                vel = msg_dict['velocity']
                if vel > 0:
                    # Using a list for the active notes becuase note 71 in io.mid was definied twice at once
                    if active_notes.has_key(msg_dict['note']):
                        active_notes[msg_dict['note']].append({'time':time,'velocity':vel})
                    else:
                        active_notes[msg_dict['note']] = [{'time':time, 'velocity': vel}]
                elif vel == 0:
                    note = msg_dict['note']
                    start_msg = active_notes[note].pop()
                    new_note = {'note': note, 'start': start_msg['time'],
                                'end': time, 'velocity': start_msg['velocity']}
                    all_notes[i].append(new_note)
    return all_notes

# %%
def create_streams(all_notes):
    streams = []
    for notes in all_notes:
        while notes != []:
            stream = []
            vel = 0
            current_end = 0
            for note in notes:
                if note['start'] >= current_end:
                    if note['velocity'] != vel:
                        vel = note['velocity']
                    else:
                        del note['velocity']
                    stream.append(note)
                    current_end = note['end']
            streams.append(stream)
            for note in stream:
                notes.remove(note)
    return streams

# %%
def streams_to_cells(streams, speed):
    max_time = int(max([x['end'] for x in [item for sublist in streams for item in sublist]]))
    start_cells = 'A2:A' + str(1+len(streams))
    instructions = 'r m' + str(max_time-1)
    turtles = [['!turtle(' + start_cells + ', ' + instructions + ', ' + str(speed) + ', 1)']]
    for stream in streams:
        cells = [""] * max_time
        for note in stream:
            start = int(note['start'])
            cells[start] = audiolazy.midi2str(note['note'])
            if note.has_key('velocity'):
                cells[start] += (' ' + str(round(float(note['velocity'])/127,2)))
            for rest_duration in range(1,int(note['length'])):
                cells[start+rest_duration] = '-'
        turtles.append(cells)
    print(str(len(turtles)) + ' x ' + str(max([len(stream) for stream in turtles])))
    return turtles

# %%
def midi_to_excello(file_name, method=1):
    # Fetch MIDI file
    mid = mido.MidiFile(file_name) 
    tempo = [m.dict()['tempo'] for m in mid.tracks[0] if m.dict().has_key('tempo')][0]
    ticks_per_beat = mid.ticks_per_beat
    # Extract the notes from as onset, note, offset, volume from messages
    all_notes = get_active_notes(mid)
    # Split into the streams as played by individual turtles
    streams = create_streams(all_notes)
    all_notes = [item for sublist in streams for item in sublist]
    print('Number of turtles: ' + str(len(streams)))
    
    # No Compression
    if method == 0:
        print("No Compression")
        difference_stat = 1
        ratio_int = 1
        for stream in streams:
            for note in stream:
                note['length'] = note['end'] - note['start']
    #Compression
    else:
        differences = [(y['start']-x['start']) for x, y in zip(all_notes[:-1], all_notes[1:])]
        lengths = [(x['end'] - x['start']) for x in [item for sublist in streams for item in sublist]]
        # Mins
        if method == 1:
            print("Min Compression")
            difference_stat = min([x for x in differences if x > 0])
            length_stat = min([x for x in lengths if x > 0])
        # Modes 
        elif method == 2:
            print("Mode Compression")
            difference_stat = max(set(differences), key=differences.count)
            length_stat = max(set(lengths), key=lengths.count)

        print('note difference stat: ' + str(difference_stat))
        print('note length stat: ' + str(length_stat))

        mode_ratio = (float(max(difference_stat, length_stat)) / min(difference_stat, length_stat))
        print('mode ratio: ' + str(mode_ratio))
        ratio_int = int(mode_ratio)
        print('integer ratio: ' + str(ratio_int))
        ratio_correction = mode_ratio/ratio_int
        print('ratio correction: ' + str(ratio_correction))
    
        # Convert MIDI times to cell times
        rounding_base = 0.1
        for stream in streams:
            for note in stream:
                note['length'] = ((float(note['end']) - note['start'])/length_stat) 
                note['length'] = rounding_base * round(note['length']/rounding_base)
                note['start'] = round(rounding_base * round((float(note['start'])/difference_stat*ratio_int)/rounding_base))
                note['end'] = note['start'] + note['length']
            
    speed = int(round((float(60*10**6)/tempo) * ticks_per_beat * (float(ratio_int)/difference_stat)))
    print(speed)
            
    csv_name = file_name.split('.')[0] + '.csv'
    with open(csv_name, "wb") as f:
        writer = csv.writer(f)
        writer.writerows(streams_to_cells(streams, speed))
    print("Written to " + csv_name)

# %% [markdown]
# # Converting

# %% [markdown]
# 0: No Compression<br>
# 1: Compression using Minimum difference<br>
# 2: Compression using Modal difference

# %%
file_name = 'io.mid'

# %%
midi_to_excello(file_name, 0)
# Out:
# Number of turtles: 6
# No Compression
# 69696
# 7 x 32819
# Written to io.csv

# %% [markdown]
# # Old stuff

# %%
m = mido.MidiFile("io.mid")

# %%
streams = create_streams(get_active_notes(m))

# %%
streams
# Out:
# [[{'end': 719, 'note': 83, 'start': 0, 'velocity': 49},
#   {'end': 1439, 'note': 83, 'start': 720},
#   {'end': 1679, 'note': 81, 'start': 1440},
#   {'end': 1919, 'note': 79, 'start': 1680},
#   {'end': 2159, 'note': 81, 'start': 1920},
#   {'end': 2639, 'note': 83, 'start': 2160},
#   {'end': 3359, 'note': 79, 'start': 2640},
#   {'end': 3599, 'note': 81, 'start': 3360},
#   {'end': 3839, 'note': 79, 'start': 3600},
#   {'end': 4079, 'note': 78, 'start': 3840},
#   {'end': 4559, 'note': 83, 'start': 4080},
#   {'end': 5279, 'note': 79, 'start': 4560},
#   {'end': 5519, 'note': 81, 'start': 5280},
#   {'end': 5759, 'note': 79, 'start': 5520},
#   {'end': 5999, 'note': 78, 'start': 5760},
#   {'end': 6479, 'note': 83, 'start': 6000},
#   {'end': 6959, 'note': 84, 'start': 6480},
#   {'end': 7199, 'note': 84, 'start': 6960},
#   {'end': 7439, 'note': 83, 'start': 7200},
#   {'end': 7679, 'note': 79, 'start': 7440},
#   {'end': 8399, 'note': 77, 'start': 7680},
#   {'end': 9119, 'note': 81, 'start': 8400},
#   {'end': 9359, 'note': 79, 'start': 9120},
#   {'end': 9599, 'note': 77, 'start': 9360},
#   {'end': 9839, 'note': 79, 'start': 9600},
#   {'end': 10319, 'note': 81, 'start': 9840},
#   {'end': 11039, 'note': 77, 'start': 10320},
#   {'end': 11279, 'note': 79, 'start': 11040},
#   {'end': 11519, 'note': 77, 'start': 11280},
#   {'end': 11759, 'note': 76, 'start': 11520},
#   {'end': 12239, 'note': 81, 'start': 11760},
#   {'end': 12959, 'note': 77, 'start': 12240},
#   {'end': 13199, 'note': 79, 'start': 12960},
#   {'end': 13439, 'note': 77, 'start': 13200},
#   {'end': 13679, 'note': 76, 'start': 13440},
#   {'end': 14159, 'note': 81, 'start': 13680},
#   {'end': 14399, 'note': 81, 'start': 14160},
#   {'end': 14639, 'note': 84, 'start': 14400},
#   {'end': 14879, 'note': 83, 'start': 14640},
#   {'end': 15119, 'note': 81, 'start': 14880},
#   {'end': 15359, 'note': 79, 'start': 15120},
#   {'end': 16079, 'note': 62, 'start': 15360, 'velocity': 64},
#   {'end': 16199, 'note': 71, 'start': 16080},
#   {'end': 17039, 'note': 69, 'start': 16800},
#   {'end': 17279, 'note': 67, 'start': 17040},
#   {'end': 17519, 'note': 69, 'start': 17280},
#   {'end': 17999, 'note': 71, 'start': 17520},
#   {'end': 18719, 'note': 67, 'start': 18000},
#   {'end': 18959, 'note': 69, 'start': 18720},
#   {'end': 19199, 'note': 67, 'start': 18960},
#   {'end': 19439, 'note': 66, 'start': 19200},
#   {'end': 19919, 'note': 71, 'start': 19440},
#   {'end': 20639, 'note': 67, 'start': 19920},
#   {'end': 20879, 'note': 69, 'start': 20640},
#   {'end': 21119, 'note': 67, 'start': 20880},
#   {'end': 21359, 'note': 66, 'start': 21120},
#   {'end': 21839, 'note': 71, 'start': 21360},
#   {'end': 22319, 'note': 72, 'start': 21840},
#   {'end': 22559, 'note': 72, 'start': 22320},
#   {'end': 22799, 'note': 71, 'start': 22560},
#   {'end': 23039, 'note': 67, 'start': 22800},
#   {'end': 23759, 'note': 57, 'start': 23040},
#   {'end': 24479, 'note': 69, 'start': 23760},
#   {'end': 24719, 'note': 67, 'start': 24480},
#   {'end': 24959, 'note': 65, 'start': 24720},
#   {'end': 25199, 'note': 67, 'start': 24960},
#   {'end': 25679, 'note': 69, 'start': 25200},
#   {'end': 26399, 'note': 65, 'start': 25680},
#   {'end': 26639, 'note': 67, 'start': 26400},
#   {'end': 26879, 'note': 65, 'start': 26640},
#   {'end': 27119, 'note': 64, 'start': 26880},
#   {'end': 27599, 'note': 69, 'start': 27120},
#   {'end': 28319, 'note': 65, 'start': 27600},
#   {'end': 28559, 'note': 67, 'start': 28320},
#   {'end': 28799, 'note': 65, 'start': 28560},
#   {'end': 29039, 'note': 64, 'start': 28800},
#   {'end': 29519, 'note': 69, 'start': 29040},
#   {'end': 29759, 'note': 64, 'start': 29520},
#   {'end': 29999, 'note': 72, 'start': 29760},
#   {'end': 30239, 'note': 71, 'start': 30000},
#   {'end': 30479, 'note': 69, 'start': 30240},
#   {'end': 30719, 'note': 67, 'start': 30480},
#   {'end': 32639, 'note': 62, 'start': 30720}],
#  [{'end': 16139, 'note': 67, 'start': 15420, 'velocity': 64},
#   {'end': 23819, 'note': 60, 'start': 23100},
#   {'end': 32699, 'note': 66, 'start': 30780}],
#  [{'end': 16799, 'note': 71, 'start': 15480, 'velocity': 64},
#   {'end': 13439, 'note': 57, 'start': 13200},
#   {'end': 13679, 'note': 53, 'start': 13440},
#   {'end': 13919, 'note': 57, 'start': 13680},
#   {'end': 14159, 'note': 53, 'start': 13920},
#   {'end': 14399, 'note': 57, 'start': 14160},
#   {'end': 14639, 'note': 53, 'start': 14400},
#   {'end': 14879, 'note': 57, 'start': 14640},
#   {'end': 15119, 'note': 53, 'start': 14880},
#   {'end': 15359, 'note': 57, 'start': 15120},
#   {'end': 15599, 'note': 43, 'start': 15360, 'velocity': 64},
#   {'end': 15839, 'note': 50, 'start': 15600},
#   {'end': 16079, 'note': 55, 'start': 15840},
#   {'end': 16319, 'note': 59, 'start': 16080},
#   {'end': 16559, 'note': 55, 'start': 16320},
#   {'end': 16799, 'note': 59, 'start': 16560},
#   {'end': 17039, 'note': 55, 'start': 16800},
#   {'end': 17279, 'note': 59, 'start': 17040},
#   {'end': 17519, 'note': 55, 'start': 17280},
#   {'end': 17759, 'note': 59, 'start': 17520},
#   {'end': 17999, 'note': 55, 'start': 17760},
#   {'end': 18239, 'note': 59, 'start': 18000},
#   {'end': 18479, 'note': 55, 'start': 18240},
#   {'end': 18719, 'note': 59, 'start': 18480},
#   {'end': 18959, 'note': 55, 'start': 18720},
#   {'end': 19199, 'note': 59, 'start': 18960},
#   {'end': 19439, 'note': 43, 'start': 19200},
#   {'end': 19679, 'note': 50, 'start': 19440},
#   {'end': 19919, 'note': 55, 'start': 19680},
#   {'end': 20159, 'note': 59, 'start': 19920},
#   {'end': 20399, 'note': 55, 'start': 20160},
#   {'end': 20639, 'note': 59, 'start': 20400},
#   {'end': 20879, 'note': 55, 'start': 20640},
#   {'end': 21119, 'note': 59, 'start': 20880},
#   {'end': 21359, 'note': 55, 'start': 21120},
#   {'end': 21599, 'note': 59, 'start': 21360},
#   {'end': 21839, 'note': 55, 'start': 21600},
#   {'end': 22079, 'note': 59, 'start': 21840},
#   {'end': 22319, 'note': 55, 'start': 22080},
#   {'end': 22559, 'note': 59, 'start': 22320},
#   {'end': 22799, 'note': 55, 'start': 22560},
#   {'end': 23039, 'note': 59, 'start': 22800},
#   {'end': 23279, 'note': 41, 'start': 23040},
#   {'end': 23519, 'note': 48, 'start': 23280},
#   {'end': 23759, 'note': 53, 'start': 23520},
#   {'end': 23999, 'note': 57, 'start': 23760},
#   {'end': 24239, 'note': 53, 'start': 24000},
#   {'end': 24479, 'note': 57, 'start': 24240},
#   {'end': 24719, 'note': 53, 'start': 24480},
#   {'end': 24959, 'note': 57, 'start': 24720},
#   {'end': 25199, 'note': 53, 'start': 24960},
#   {'end': 25439, 'note': 57, 'start': 25200},
#   {'end': 25679, 'note': 53, 'start': 25440},
#   {'end': 25919, 'note': 57, 'start': 25680},
#   {'end': 26159, 'note': 53, 'start': 25920},
#   {'end': 26399, 'note': 57, 'start': 26160},
#   {'end': 26639, 'note': 53, 'start': 26400},
#   {'end': 26879, 'note': 57, 'start': 26640},
#   {'end': 27119, 'note': 41, 'start': 26880},
#   {'end': 27359, 'note': 48, 'start': 27120},
#   {'end': 27599, 'note': 53, 'start': 27360},
#   {'end': 27839, 'note': 57, 'start': 27600},
#   {'end': 28079, 'note': 53, 'start': 27840},
#   {'end': 28319, 'note': 57, 'start': 28080},
#   {'end': 28559, 'note': 53, 'start': 28320},
#   {'end': 28799, 'note': 57, 'start': 28560},
#   {'end': 29039, 'note': 53, 'start': 28800},
#   {'end': 29279, 'note': 57, 'start': 29040},
#   {'end': 29519, 'note': 53, 'start': 29280},
#   {'end': 29759, 'note': 57, 'start': 29520},
#   {'end': 30719, 'note': 53, 'start': 29760},
#   {'end': 32639, 'note': 55, 'start': 30720}],
#  [{'end': 32639, 'note': 43, 'start': 30720, 'velocity': 64}]]

# %% [markdown]
# #### import pygame

# %%
def play_music(music_file):
    """
    stream music with mixer.music module in blocking manner
    this will stream the sound from disk while playing
    """
    clock = pygame.time.Clock()
    try:
        pygame.mixer.music.load(music_file)
        print "Music file %s loaded!" % music_file
    except pygame.error:
        print "File %s not found! (%s)" % (music_file, pygame.get_error())
        return
    pygame.mixer.music.play()
    while pygame.mixer.music.get_busy():
        # check if playback has finished
        clock.tick(30)
# pick a midi music file you have ...
# (if not in working folder use full path)

freq = 44100    # audio CD quality
bitsize = -16   # unsigned 16 bit
channels = 2    # 1 is mono, 2 is stereo
buffer = 1024    # number of samples
pygame.mixer.init(freq, bitsize, channels, buffer)

# %%
play_music(file_name)
# Out:
# Music file bach_850.mid loaded!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a8c69e221f94> in <module>()
# ----> 1 play_music(file_name)
#
# <ipython-input-2-81ce79f6a1fb> in play_music(music_file)
#      14     while pygame.mixer.music.get_busy():
#      15         # check if playback has finished
# ---> 16         clock.tick(30)
#      17 # pick a midi music file you have ...
#      18 # (if not in working folder use full path)
#
# KeyboardInterrupt:

# %%
mid = mido.MidiFile(file_name)

# %%
list(mid.tracks[0])
# Out:
# [<meta message time_signature numerator=4 denominator=4 clocks_per_click=24 notated_32nd_notes_per_beat=8 time=0>,
#  <meta message key_signature key='A' time=0>,
#  <meta message set_tempo tempo=526316 time=0>,
#  <message control_change channel=0 control=121 value=0 time=0>,
#  <message program_change channel=0 program=0 time=0>,
#  <message control_change channel=0 control=7 value=100 time=0>,
#  <message control_change channel=0 control=10 value=64 time=0>,
#  <message control_change channel=0 control=91 value=0 time=0>,
#  <message control_change channel=0 control=93 value=0 time=0>,
#  <meta message midi_port port=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=239>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=241>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=69 velocity=80 time=121>,
#  <message note_on channel=0 note=73 velocity=80 time=0>,
#  <message note_on channel=0 note=69 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=361>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=361>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=61 velocity=80 time=1081>,
#  <message note_on channel=0 note=61 velocity=0 time=239>,
#  <message note_on channel=0 note=62 velocity=80 time=1>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=121>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=69 velocity=80 time=121>,
#  <message note_on channel=0 note=73 velocity=80 time=0>,
#  <message note_on channel=0 note=69 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=361>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=361>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=227>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=13>,
#  <message note_on channel=0 note=68 velocity=80 time=0>,
#  <message note_on channel=0 note=76 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=683>,
#  <message note_on channel=0 note=68 velocity=0 time=0>,
#  <message note_on channel=0 note=76 velocity=0 time=0>,
#  <message note_on channel=0 note=63 velocity=80 time=37>,
#  <message note_on channel=0 note=67 velocity=80 time=0>,
#  <message note_on channel=0 note=75 velocity=80 time=0>,
#  <message note_on channel=0 note=63 velocity=0 time=227>,
#  <message note_on channel=0 note=67 velocity=0 time=0>,
#  <message note_on channel=0 note=75 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=13>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=74 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=239>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=74 velocity=0 time=0>,
#  <message note_on channel=0 note=68 velocity=80 time=721>,
#  <message note_on channel=0 note=68 velocity=0 time=239>,
#  <message note_on channel=0 note=73 velocity=80 time=241>,
#  <message note_on channel=0 note=73 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=80 time=121>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=80 time=361>,
#  <message note_on channel=0 note=73 velocity=0 time=119>,
#  <message note_on channel=0 note=68 velocity=80 time=361>,
#  <message note_on channel=0 note=68 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=80 time=361>,
#  <message note_on channel=0 note=73 velocity=0 time=119>,
#  <message note_on channel=0 note=67 velocity=80 time=361>,
#  <message note_on channel=0 note=67 velocity=0 time=239>,
#  <message note_on channel=0 note=66 velocity=80 time=1>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=61 velocity=80 time=361>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=61 velocity=0 time=119>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=361>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=121>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=121>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=841>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=121>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=121>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=56 velocity=80 time=841>,
#  <message note_on channel=0 note=59 velocity=80 time=0>,
#  <message note_on channel=0 note=63 velocity=80 time=0>,
#  <message note_on channel=0 note=56 velocity=0 time=455>,
#  <message note_on channel=0 note=59 velocity=0 time=0>,
#  <message note_on channel=0 note=63 velocity=0 time=0>,
#  <message note_on channel=0 note=55 velocity=80 time=25>,
#  <message note_on channel=0 note=58 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=0>,
#  <message note_on channel=0 note=55 velocity=0 time=455>,
#  <message note_on channel=0 note=58 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=25>,
#  <message note_on channel=0 note=57 velocity=80 time=0>,
#  <message note_on channel=0 note=61 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=239>,
#  <message note_on channel=0 note=57 velocity=0 time=0>,
#  <message note_on channel=0 note=61 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=241>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=69 velocity=80 time=121>,
#  <message note_on channel=0 note=73 velocity=80 time=0>,
#  <message note_on channel=0 note=69 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=361>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=63 velocity=80 time=361>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=63 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=68 velocity=80 time=361>,
#  <message note_on channel=0 note=76 velocity=80 time=0>,
#  <message note_on channel=0 note=68 velocity=0 time=119>,
#  <message note_on channel=0 note=76 velocity=0 time=0>,
#  <message note_on channel=0 note=68 velocity=80 time=121>,
#  <message note_on channel=0 note=76 velocity=80 time=0>,
#  <message note_on channel=0 note=68 velocity=0 time=119>,
#  <message note_on channel=0 note=76 velocity=0 time=0>,
#  <message note_on channel=0 note=68 velocity=80 time=121>,
#  <message note_on channel=0 note=76 velocity=80 time=0>,
#  <message note_on channel=0 note=68 velocity=0 time=119>,
#  <message note_on channel=0 note=76 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=601>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=121>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=69 velocity=80 time=121>,
#  <message note_on channel=0 note=73 velocity=80 time=0>,
#  <message note_on channel=0 note=69 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=361>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=361>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=121>,
#  <message note_on channel=0 note=68 velocity=80 time=0>,
#  <message note_on channel=0 note=73 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=911>,
#  <message note_on channel=0 note=68 velocity=0 time=0>,
#  <message note_on channel=0 note=73 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=49>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=71 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=239>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=71 velocity=0 time=0>,
#  <message note_on channel=0 note=71 velocity=80 time=721>,
#  <message note_on channel=0 note=71 velocity=0 time=227>,
#  <message note_on channel=0 note=67 velocity=80 time=13>,
#  <message note_on channel=0 note=67 velocity=0 time=227>,
#  <message note_on channel=0 note=62 velocity=80 time=13>,
#  <message note_on channel=0 note=62 velocity=0 time=227>,
#  <message note_on channel=0 note=61 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=0 time=455>,
#  <message note_on channel=0 note=71 velocity=80 time=25>,
#  <message note_on channel=0 note=71 velocity=0 time=227>,
#  <message note_on channel=0 note=67 velocity=80 time=13>,
#  <message note_on channel=0 note=67 velocity=0 time=227>,
#  <message note_on channel=0 note=61 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=0 time=227>,
#  <message note_on channel=0 note=69 velocity=80 time=13>,
#  <message note_on channel=0 note=69 velocity=0 time=227>,
#  <message note_on channel=0 note=66 velocity=80 time=13>,
#  <message note_on channel=0 note=66 velocity=0 time=227>,
#  <message note_on channel=0 note=60 velocity=80 time=13>,
#  <message note_on channel=0 note=60 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=455>,
#  <message note_on channel=0 note=65 velocity=80 time=25>,
#  <message note_on channel=0 note=65 velocity=0 time=227>,
#  <message note_on channel=0 note=62 velocity=80 time=13>,
#  <message note_on channel=0 note=62 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=59 velocity=0 time=119>,
#  <message note_on channel=0 note=61 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=59 velocity=80 time=121>,
#  <message note_on channel=0 note=61 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=59 velocity=0 time=119>,
#  <message note_on channel=0 note=61 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=59 velocity=80 time=121>,
#  <message note_on channel=0 note=61 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=59 velocity=0 time=119>,
#  <message note_on channel=0 note=61 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=70 velocity=80 time=1081>,
#  <message note_on channel=0 note=70 velocity=0 time=239>,
#  <message note_on channel=0 note=71 velocity=80 time=1>,
#  <message note_on channel=0 note=71 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=80 time=121>,
#  <message note_on channel=0 note=73 velocity=0 time=239>,
#  <message note_on channel=0 note=74 velocity=80 time=1>,
#  <message note_on channel=0 note=74 velocity=0 time=119>,
#  <message note_on channel=0 note=78 velocity=80 time=121>,
#  <message note_on channel=0 note=78 velocity=0 time=239>,
#  <message note_on channel=0 note=81 velocity=80 time=1>,
#  <message note_on channel=0 note=81 velocity=0 time=239>,
#  <message note_on channel=0 note=57 velocity=80 time=1681>,
#  <message note_on channel=0 note=57 velocity=0 time=455>,
#  <message note_on channel=0 note=58 velocity=80 time=25>,
#  <message note_on channel=0 note=58 velocity=0 time=455>,
#  <message note_on channel=0 note=59 velocity=80 time=25>,
#  <message note_on channel=0 note=59 velocity=0 time=683>,
#  <message note_on channel=0 note=58 velocity=80 time=37>,
#  <message note_on channel=0 note=58 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=1367>,
#  <message note_on channel=0 note=57 velocity=80 time=73>,
#  <message note_on channel=0 note=57 velocity=0 time=227>,
#  <message note_on channel=0 note=58 velocity=80 time=13>,
#  <message note_on channel=0 note=58 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=227>,
#  <message note_on channel=0 note=66 velocity=80 time=13>,
#  <message note_on channel=0 note=66 velocity=0 time=455>,
#  <message note_on channel=0 note=61 velocity=80 time=25>,
#  <message note_on channel=0 note=61 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=683>,
#  <message note_on channel=0 note=58 velocity=80 time=37>,
#  <message note_on channel=0 note=58 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=1823>,
#  <message note_on channel=0 note=59 velocity=80 time=97>,
#  <message note_on channel=0 note=59 velocity=0 time=455>,
#  <message note_on channel=0 note=60 velocity=80 time=25>,
#  <message note_on channel=0 note=60 velocity=0 time=455>,
#  <message note_on channel=0 note=61 velocity=80 time=25>,
#  <message note_on channel=0 note=61 velocity=0 time=683>,
#  <message note_on channel=0 note=60 velocity=80 time=37>,
#  <message note_on channel=0 note=60 velocity=0 time=227>,
#  <message note_on channel=0 note=61 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=0 time=1367>,
#  <message note_on channel=0 note=61 velocity=80 time=73>,
#  <message note_on channel=0 note=61 velocity=0 time=227>,
#  <message note_on channel=0 note=60 velocity=80 time=13>,
#  <message note_on channel=0 note=60 velocity=0 time=227>,
#  <message note_on channel=0 note=61 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=0 time=227>,
#  <message note_on channel=0 note=68 velocity=80 time=13>,
#  <message note_on channel=0 note=68 velocity=0 time=455>,
#  <message note_on channel=0 note=63 velocity=80 time=25>,
#  <message note_on channel=0 note=63 velocity=0 time=227>,
#  <message note_on channel=0 note=61 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=0 time=683>,
#  <message note_on channel=0 note=63 velocity=80 time=37>,
#  <message note_on channel=0 note=63 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=683>,
#  <message note_on channel=0 note=61 velocity=80 time=37>,
#  <message note_on channel=0 note=61 velocity=0 time=227>,
#  <message note_on channel=0 note=62 velocity=80 time=13>,
#  <message note_on channel=0 note=62 velocity=0 time=227>,
#  <message note_on channel=0 note=66 velocity=80 time=13>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=455>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=25>,
#  <message note_on channel=0 note=62 velocity=0 time=227>,
#  <message note_on channel=0 note=64 velocity=80 time=13>,
#  <message note_on channel=0 note=68 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=119>,
#  <message note_on channel=0 note=68 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=121>,
#  <message note_on channel=0 note=68 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=119>,
#  <message note_on channel=0 note=68 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=121>,
#  <message note_on channel=0 note=68 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=119>,
#  <message note_on channel=0 note=68 velocity=0 time=0>,
#  <meta message time_signature numerator=4 denominator=4 clocks_per_click=24 notated_32nd_notes_per_beat=8 time=361>,
#  <meta message key_signature key='A' time=0>,
#  <meta message set_tempo tempo=526316 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=239>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=241>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=69 velocity=80 time=121>,
#  <message note_on channel=0 note=73 velocity=80 time=0>,
#  <message note_on channel=0 note=69 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=361>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=361>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=61 velocity=80 time=1081>,
#  <message note_on channel=0 note=61 velocity=0 time=239>,
#  <message note_on channel=0 note=62 velocity=80 time=1>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=121>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=69 velocity=80 time=121>,
#  <message note_on channel=0 note=73 velocity=80 time=0>,
#  <message note_on channel=0 note=69 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=361>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=361>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=227>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=13>,
#  <message note_on channel=0 note=68 velocity=80 time=0>,
#  <message note_on channel=0 note=76 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=683>,
#  <message note_on channel=0 note=68 velocity=0 time=0>,
#  <message note_on channel=0 note=76 velocity=0 time=0>,
#  <message note_on channel=0 note=63 velocity=80 time=37>,
#  <message note_on channel=0 note=67 velocity=80 time=0>,
#  <message note_on channel=0 note=75 velocity=80 time=0>,
#  <message note_on channel=0 note=63 velocity=0 time=227>,
#  <message note_on channel=0 note=67 velocity=0 time=0>,
#  <message note_on channel=0 note=75 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=13>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=74 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=239>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=74 velocity=0 time=0>,
#  <message note_on channel=0 note=68 velocity=80 time=721>,
#  <message note_on channel=0 note=68 velocity=0 time=239>,
#  <message note_on channel=0 note=73 velocity=80 time=241>,
#  <message note_on channel=0 note=73 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=80 time=121>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=80 time=361>,
#  <message note_on channel=0 note=73 velocity=0 time=119>,
#  <message note_on channel=0 note=68 velocity=80 time=361>,
#  <message note_on channel=0 note=68 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=80 time=361>,
#  <message note_on channel=0 note=73 velocity=0 time=119>,
#  <message note_on channel=0 note=67 velocity=80 time=361>,
#  <message note_on channel=0 note=67 velocity=0 time=239>,
#  <message note_on channel=0 note=66 velocity=80 time=1>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=61 velocity=80 time=361>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=61 velocity=0 time=119>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=361>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=121>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=121>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=841>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=121>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=121>,
#  <message note_on channel=0 note=60 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=119>,
#  <message note_on channel=0 note=60 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=56 velocity=80 time=841>,
#  <message note_on channel=0 note=59 velocity=80 time=0>,
#  <message note_on channel=0 note=63 velocity=80 time=0>,
#  <message note_on channel=0 note=56 velocity=0 time=455>,
#  <message note_on channel=0 note=59 velocity=0 time=0>,
#  <message note_on channel=0 note=63 velocity=0 time=0>,
#  <message note_on channel=0 note=55 velocity=80 time=25>,
#  <message note_on channel=0 note=58 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=0>,
#  <message note_on channel=0 note=55 velocity=0 time=455>,
#  <message note_on channel=0 note=58 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=0>,
#  <message note_on channel=0 note=54 velocity=80 time=25>,
#  <message note_on channel=0 note=57 velocity=80 time=0>,
#  <message note_on channel=0 note=61 velocity=80 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=239>,
#  <message note_on channel=0 note=57 velocity=0 time=0>,
#  <message note_on channel=0 note=61 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=241>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=69 velocity=80 time=121>,
#  <message note_on channel=0 note=73 velocity=80 time=0>,
#  <message note_on channel=0 note=69 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=361>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=63 velocity=80 time=361>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=63 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=121>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=68 velocity=80 time=361>,
#  <message note_on channel=0 note=76 velocity=80 time=0>,
#  <message note_on channel=0 note=68 velocity=0 time=119>,
#  <message note_on channel=0 note=76 velocity=0 time=0>,
#  <message note_on channel=0 note=68 velocity=80 time=121>,
#  <message note_on channel=0 note=76 velocity=80 time=0>,
#  <message note_on channel=0 note=68 velocity=0 time=119>,
#  <message note_on channel=0 note=76 velocity=0 time=0>,
#  <message note_on channel=0 note=68 velocity=80 time=121>,
#  <message note_on channel=0 note=76 velocity=80 time=0>,
#  <message note_on channel=0 note=68 velocity=0 time=119>,
#  <message note_on channel=0 note=76 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=601>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=121>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=69 velocity=80 time=121>,
#  <message note_on channel=0 note=73 velocity=80 time=0>,
#  <message note_on channel=0 note=69 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=0 time=0>,
#  <message note_on channel=0 note=66 velocity=80 time=361>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=119>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=361>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=119>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=121>,
#  <message note_on channel=0 note=68 velocity=80 time=0>,
#  <message note_on channel=0 note=73 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=911>,
#  <message note_on channel=0 note=68 velocity=0 time=0>,
#  <message note_on channel=0 note=73 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=49>,
#  <message note_on channel=0 note=66 velocity=80 time=0>,
#  <message note_on channel=0 note=71 velocity=80 time=0>,
#  <message note_on channel=0 note=62 velocity=0 time=239>,
#  <message note_on channel=0 note=66 velocity=0 time=0>,
#  <message note_on channel=0 note=71 velocity=0 time=0>,
#  <message note_on channel=0 note=71 velocity=80 time=721>,
#  <message note_on channel=0 note=71 velocity=0 time=227>,
#  <message note_on channel=0 note=67 velocity=80 time=13>,
#  <message note_on channel=0 note=67 velocity=0 time=227>,
#  <message note_on channel=0 note=62 velocity=80 time=13>,
#  <message note_on channel=0 note=62 velocity=0 time=227>,
#  <message note_on channel=0 note=61 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=0 time=455>,
#  <message note_on channel=0 note=71 velocity=80 time=25>,
#  <message note_on channel=0 note=71 velocity=0 time=227>,
#  <message note_on channel=0 note=67 velocity=80 time=13>,
#  <message note_on channel=0 note=67 velocity=0 time=227>,
#  <message note_on channel=0 note=61 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=0 time=227>,
#  <message note_on channel=0 note=69 velocity=80 time=13>,
#  <message note_on channel=0 note=69 velocity=0 time=227>,
#  <message note_on channel=0 note=66 velocity=80 time=13>,
#  <message note_on channel=0 note=66 velocity=0 time=227>,
#  <message note_on channel=0 note=60 velocity=80 time=13>,
#  <message note_on channel=0 note=60 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=455>,
#  <message note_on channel=0 note=65 velocity=80 time=25>,
#  <message note_on channel=0 note=65 velocity=0 time=227>,
#  <message note_on channel=0 note=62 velocity=80 time=13>,
#  <message note_on channel=0 note=62 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=59 velocity=0 time=119>,
#  <message note_on channel=0 note=61 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=59 velocity=80 time=121>,
#  <message note_on channel=0 note=61 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=59 velocity=0 time=119>,
#  <message note_on channel=0 note=61 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=59 velocity=80 time=121>,
#  <message note_on channel=0 note=61 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=0>,
#  <message note_on channel=0 note=59 velocity=0 time=119>,
#  <message note_on channel=0 note=61 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=0>,
#  <message note_on channel=0 note=70 velocity=80 time=1081>,
#  <message note_on channel=0 note=70 velocity=0 time=239>,
#  <message note_on channel=0 note=71 velocity=80 time=1>,
#  <message note_on channel=0 note=71 velocity=0 time=119>,
#  <message note_on channel=0 note=73 velocity=80 time=121>,
#  <message note_on channel=0 note=73 velocity=0 time=239>,
#  <message note_on channel=0 note=74 velocity=80 time=1>,
#  <message note_on channel=0 note=74 velocity=0 time=119>,
#  <message note_on channel=0 note=78 velocity=80 time=121>,
#  <message note_on channel=0 note=78 velocity=0 time=239>,
#  <message note_on channel=0 note=81 velocity=80 time=1>,
#  <message note_on channel=0 note=81 velocity=0 time=239>,
#  <message note_on channel=0 note=57 velocity=80 time=1681>,
#  <message note_on channel=0 note=57 velocity=0 time=455>,
#  <message note_on channel=0 note=58 velocity=80 time=25>,
#  <message note_on channel=0 note=58 velocity=0 time=455>,
#  <message note_on channel=0 note=59 velocity=80 time=25>,
#  <message note_on channel=0 note=59 velocity=0 time=683>,
#  <message note_on channel=0 note=58 velocity=80 time=37>,
#  <message note_on channel=0 note=58 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=1367>,
#  <message note_on channel=0 note=57 velocity=80 time=73>,
#  <message note_on channel=0 note=57 velocity=0 time=227>,
#  <message note_on channel=0 note=58 velocity=80 time=13>,
#  <message note_on channel=0 note=58 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=227>,
#  <message note_on channel=0 note=66 velocity=80 time=13>,
#  <message note_on channel=0 note=66 velocity=0 time=455>,
#  <message note_on channel=0 note=61 velocity=80 time=25>,
#  <message note_on channel=0 note=61 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=683>,
#  <message note_on channel=0 note=58 velocity=80 time=37>,
#  <message note_on channel=0 note=58 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=1823>,
#  <message note_on channel=0 note=59 velocity=80 time=97>,
#  <message note_on channel=0 note=59 velocity=0 time=455>,
#  <message note_on channel=0 note=60 velocity=80 time=25>,
#  <message note_on channel=0 note=60 velocity=0 time=455>,
#  <message note_on channel=0 note=61 velocity=80 time=25>,
#  <message note_on channel=0 note=61 velocity=0 time=683>,
#  <message note_on channel=0 note=60 velocity=80 time=37>,
#  <message note_on channel=0 note=60 velocity=0 time=227>,
#  <message note_on channel=0 note=61 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=0 time=1367>,
#  <message note_on channel=0 note=61 velocity=80 time=73>,
#  <message note_on channel=0 note=61 velocity=0 time=227>,
#  <message note_on channel=0 note=60 velocity=80 time=13>,
#  <message note_on channel=0 note=60 velocity=0 time=227>,
#  <message note_on channel=0 note=61 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=0 time=227>,
#  <message note_on channel=0 note=68 velocity=80 time=13>,
#  <message note_on channel=0 note=68 velocity=0 time=455>,
#  <message note_on channel=0 note=63 velocity=80 time=25>,
#  <message note_on channel=0 note=63 velocity=0 time=227>,
#  <message note_on channel=0 note=61 velocity=80 time=13>,
#  <message note_on channel=0 note=61 velocity=0 time=683>,
#  <message note_on channel=0 note=63 velocity=80 time=37>,
#  <message note_on channel=0 note=63 velocity=0 time=227>,
#  <message note_on channel=0 note=59 velocity=80 time=13>,
#  <message note_on channel=0 note=59 velocity=0 time=683>,
#  <message note_on channel=0 note=61 velocity=80 time=37>,
#  <message note_on channel=0 note=61 velocity=0 time=227>,
#  <message note_on channel=0 note=62 velocity=80 time=13>,
#  <message note_on channel=0 note=62 velocity=0 time=227>,
#  <message note_on channel=0 note=66 velocity=80 time=13>,
#  <message note_on channel=0 note=69 velocity=80 time=0>,
#  <message note_on channel=0 note=66 velocity=0 time=455>,
#  <message note_on channel=0 note=69 velocity=0 time=0>,
#  <message note_on channel=0 note=62 velocity=80 time=25>,
#  <message note_on channel=0 note=62 velocity=0 time=227>,
#  <message note_on channel=0 note=64 velocity=80 time=13>,
#  <message note_on channel=0 note=68 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=119>,
#  <message note_on channel=0 note=68 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=121>,
#  <message note_on channel=0 note=68 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=119>,
#  <message note_on channel=0 note=68 velocity=0 time=0>,
#  <message note_on channel=0 note=64 velocity=80 time=121>,
#  <message note_on channel=0 note=68 velocity=80 time=0>,
#  <message note_on channel=0 note=64 velocity=0 time=119>,
#  <message note_on channel=0 note=68 velocity=0 time=0>,
#  <meta message end_of_track time=1>]

# %%
mid.tracks
# Out:
# [<midi track '' 706 messages>, <midi track '' 600 messages>]

# %%
all_notes = get_active_notes(mid)
# Out:
# Track 0:
# Track 1:

# %%
all_notes
# Out:
# [[{'end': 239, 'note': 62, 'start': 0, 'velocity': 80},
#   {'end': 239, 'note': 66, 'start': 0, 'velocity': 80},
#   {'end': 599, 'note': 66, 'start': 480, 'velocity': 80},
#   {'end': 599, 'note': 69, 'start': 480, 'velocity': 80},
#   {'end': 839, 'note': 69, 'start': 720, 'velocity': 80},
#   {'end': 839, 'note': 73, 'start': 720, 'velocity': 80},
#   {'end': 1319, 'note': 66, 'start': 1200, 'velocity': 80},
#   {'end': 1319, 'note': 69, 'start': 1200, 'velocity': 80},
#   {'end': 1799, 'note': 62, 'start': 1680, 'velocity': 80},
#   {'end': 1799, 'note': 66, 'start': 1680, 'velocity': 80},
#   {'end': 2039, 'note': 62, 'start': 1920, 'velocity': 80},
#   {'end': 2279, 'note': 62, 'start': 2160, 'velocity': 80},
#   {'end': 92135, 'note': 58, 'start': 91680, 'velocity': 80},
#   {'end': 92615, 'note': 42, 'start': 92160, 'velocity': 80},
#   {'end': 92615, 'note': 54, 'start': 92160, 'velocity': 80},
#   {'end': 92867, 'note': 54, 'start': 92640, 'velocity': 80},
#   {'end': 92867, 'note': 57, 'start': 92640, 'velocity': 80},
#   {'end': 93335, 'note': 47, 'start': 92880, 'velocity': 80},
#   {'end': 94043, 'note': 54, 'start': 93360, 'velocity': 80},
#   {'end': 94043, 'note': 57, 'start': 93360, 'velocity': 80},
#   {'end': 94991, 'note': 40, 'start': 94080, 'velocity': 80},
#   {'end': 94991, 'note': 52, 'start': 94080, 'velocity': 80},
#   {'end': 95159, 'note': 59, 'start': 95040, 'velocity': 80},
#   {'end': 95159, 'note': 61, 'start': 95040, 'velocity': 80},
#   {'end': 95399, 'note': 59, 'start': 95280, 'velocity': 80},
#   {'end': 95399, 'note': 61, 'start': 95280, 'velocity': 80},
#   {'end': 95639, 'note': 59, 'start': 95520, 'velocity': 80},
#   {'end': 95639, 'note': 61, 'start': 95520, 'velocity': 80}]]

# %% [markdown]
# Split into single note at a time tracks

# %%
streams = create_streams(all_notes)

# %% [markdown]
# Calculate cell length

# %%
all_notes = [item for sublist in streams for item in sublist]

# %%
differences = [(y['start']-x['start']) for x, y in zip(all_notes[:-1], all_notes[1:])]
mode_difference = max(set(differences), key=differences.count)
min_difference = min([x for x in differences if x > 0])
mode_difference = min_difference

# %%
lengths = [(x['end'] - x['start']) for x in [item for sublist in streams for item in sublist]]
mode_length = max(set(lengths), key=lengths.count)
min_length = min(lengths)
mode_length = min_length

# %%
mode_difference

# %%
mode_length

# %%
mode = mode_length

# %%
mode

# %%
ratio = (float(mode_difference) / mode_length)/(mode_difference / mode_length)

# %%
ratio_int = (mode_difference / mode_length)

# %%
ratio

# %%
ratio_int

# %%
for stream in streams:
    for note in stream:
        note['length'] = ((float(note['end']) - note['start'])/mode)

# %%
streams

# %%
rounding_base = 0.1
for stream in streams:
    for note in stream:
        note['length'] = rounding_base * round(note['length']/rounding_base)
        note['start'] = round(rounding_base * round((float(note['start'])/mode_difference*ratio_int)/rounding_base))
        note['end'] = note['start'] + note['length']

# %%
streams

# %% [markdown]
# Create list for cells in that single turtle track

# %%
max_time = int(max([x['end'] for x in [item for sublist in streams for item in sublist]]))
start_cells = 'A2:A' + str(1+num_turtles)
instructions = 'r m' + str(max_time-1)
speed = 1
turtles = [['!turtle(' + start_cells + ', ' + instructions + ', ' + str(speed) + ', 1)']]
for stream in streams:
    cells = [""] * max_time
    for note in stream:
        start = int(note['start'])
        cells[start] = audiolazy.midi2str(note['note'])
        if note.has_key('velocity'):
            cells[start] += (' ' + str(round(float(note['velocity'])/127,2)))
        for rest_duration in range(1,int(note['length'])):
            cells[start+rest_duration] = '-'
    turtles.append(cells)

# %% [markdown]
# Combine lists into csv

# %%
csv_name = file_name.split('.')[0] + '.csv'
with open(csv_name, "wb") as f:
    writer = csv.writer(f)
    writer.writerows(turtles)
